# %%
import pandas as pd

airbnb = pd.read_csv("listings dec21.csv")


list(airbnb.columns)

new_airbnb = airbnb[["name", "latitude", "longitude", "bedrooms", "price"]]

# %%
new_airbnb
# Out:
#                                                     name   latitude  \
# 0                   Belém 1 Bedroom Historical Apartment  38.697500
# 1       Heart of Alfama Lisbon Center - Cœur de l'Alfama  38.712410
# 2               Apartamento Alfama com vista para o rio!  38.710820
# 3                       Alfama Hill - Boutique apartment  38.711560
# 4                            TheHOUSE - Your luxury home  38.711080
# ...                                                  ...        ...
# 18521                    Zen Nest in the heart of Lisbon  38.721587
# 18522  NEW! Charming 2 bed w/patio in historical Mour...  38.716469
# 18523                            New Avenues Dreamy Home  38.740442
# 18524                              Alfama Top Location 2  38.715410
# 18525  Stunning Apartment in Heart of Lisbon by Lovel...  38.709519
#
#        longitude  bedrooms    price
# 0      -9.197680       1.0   $40.00
# 1      -9.127060       1.0   $50.00
# 2      -9.127190       1.0   $60.00
# ...
